# %% [markdown]
#  Name    : Malini D
#
#  Roll.No : CB.SC.I5DAS20118

# %% [markdown]
# #                                BUSINESS ANALYTICS ASSIGNMENT 2
# #

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Malini\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # 1.Understand the variables that make up this dataset. The dataset includes several personal and job-related variables such as Age, Gender, Marital Status, Business Travel, Daily Rate, Department, Distance From Home, Education, Education Field, Employee Count, Employee Number, Environment Satisfaction Hoursly Rate and so on. Knowing what each variable is individually will help when exploring employee attrition as a whole.

# %%
import pandas as pd

# Display basic information about the dataset
print("Dataset Information:")
print(df.info())

# Display summary statistics for numerical variables
print("\nSummary Statistics for Numerical Variables:")
print(df.describe())

# Display unique values for categorical variables
print("\nUnique Values for Categorical Variables:")
categorical_variables = df.select_dtypes(include=['object']).columns
for column in categorical_variables:
    print(f"{column}: {df[column].unique()}")

# Display the first few rows of the dataset
print("\nFirst Few Rows of the Dataset:")
print(df.head())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %% [markdown]
# insight :
#     Understanding the age distribution can help identify if there are specific age groups more prone to attrition.so that Tailor retention strategies or career development programs to address the needs and expectations of different age groups can be found.
#     Assessing gender distribution may reveal if there are gender-related patterns in attrition to ensure diversity and inclusion initiatives, and address any potential gender-specific concerns
#     Analyzing marital status can uncover whether single or married employees are more likely to leave and implement support programs for employees with specific marital statuses, such as family-friendly policies or counseling services.
#     similarly insights can be found based on each feature

# %% [markdown]
# # 2.Analyze the data for patterns as well as outliers or anomalies either at an individual level or across all of the data points together. Identifying these patterns or discrepancies can offer insight into factors that are related to employee attrition.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Explore distribution of numeric variables
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle("Distribution of Numeric Variables")
plt.show()

# Explore attrition distribution
sns.countplot(x='Attrition', data=df)
plt.title("Attrition Distribution")
plt.show()

# Box plot for numerical variables with respect to Attrition
for col in numeric_cols:
    sns.boxplot(x='Attrition', y=col, data=df)
    plt.title(f"{col} vs. Attrition")
    plt.show()
# Out:
# Missing values:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %% [markdown]
# Insight : Box plots reveal the distribution of numeric variables across different attrition categories.so that we can Identify any significant differences in the distribution of numeric variables for employees with and without attrition.
# Understanding the overall distribution of numeric variables, which may reveal potential patterns or outliers.
# Understanding the distribution of the target variable, which is essential for building a predictive model.

# %% [markdown]
# # 3.Visualize the data using charts and graphs to allow for easy understanding of which relationships might be causing higher levels of employees leaving the organization over time dimensions like age or job role can be key factors in employee attrition rates visually displaying how they relate to one another can provide clarity into what needs to change within an organization in order to reduce attrition rates

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for Seaborn plots
sns.set(style="whitegrid")

# Age distribution with respect to Attrition
plt.figure(figsize=(12, 6))
sns.histplot(x='Age', hue='Attrition', data=df, kde=True, bins=30)
plt.title("Age Distribution with respect to Attrition")
plt.xlabel("Age")
plt.show()

# Job role distribution with respect to Attrition
plt.figure(figsize=(14, 7))
sns.countplot(x='JobRole', hue='Attrition', data=df)
plt.title("Job Role Distribution with respect to Attrition")
plt.xticks(rotation=45, ha="right")
plt.show()

# Attrition across different departments
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title("Attrition Across Different Departments")
plt.show()

# %% [markdown]
# Insight : Tailor retention strategies for specific age groups if there are patterns indicating higher attrition rates in certain age ranges.
#     Target interventions or policies based on job roles with higher attrition rates. For example, if a particular role consistently experiences high attrition, investigate and address potential issues specific to that role.
#     Identifying trends and consider implementing retention strategies for employees at certain stages of their tenure.
#     These visualizations provide a clear picture of relationships between key variables and attrition.

# %% [markdown]
# # 4.Explore relationships between pairs of variables through correlation analysis correlations are measures of how strongly two variables are related when looking at employment retention it’s important to analyze correlations at both an individual level and for all variables together showing which pairings have more influence than others when it comes to influencing employee decisions.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting numerical columns for correlation analysis
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Compute the correlation matrix
correlation_matrix = df[numeric_cols].corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Numerical Variables")
plt.show()

# %% [markdown]
# Insight: The heatmap displays correlations between all pairs of variables in the dataset.Identifying strong positive or negative correlations. For example, if 'JobLevel' and 'TotalWorkingYears' have a strong positive correlation, it may indicate that employees with higher job levels tend to have more working experience.
#     Exploring how multiple variables together may influence attrition and Considering combinations of variables that show strong correlations with attrition. For example, if 'YearsInCurrentRole' and 'YearsWithCurrManager' both have strong negative correlations with attrition, it may indicate that stability in role and manager relationships contributes to employee retention.

# %% [markdown]
# # 5.Use descriptive analytics methods such as scatter plots histograms boxplots etc with aggregated values from each field like average age average monthly income etc These analytics help gain a deeper understanding about where changes need to be made internally.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for Seaborn plots
sns.set(style="whitegrid")

# Aggregating values by department for average age and average monthly income
agg_df = df.groupby('Department').agg({
    'Age': 'mean',
    'MonthlyIncome': 'mean'
}).reset_index()

# Scatter plot of Average Age vs. Average Monthly Income with department color-coded
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Age', y='MonthlyIncome', hue='Department', data=df)
plt.title("Scatter Plot of Age vs. MonthlyIncome with Department")
plt.xlabel("Age")
plt.ylabel("Monthly Income")
plt.show()

# Boxplot of Average MonthlyIncome with respect to Department
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='MonthlyIncome', data=df)
plt.title("Boxplot of MonthlyIncome with respect to Department")
plt.xlabel("Department")
plt.ylabel("Monthly Income")
plt.show()

# Histogram of Average Age by Department
plt.figure(figsize=(10, 6))
sns.histplot(x='Age', hue='Department', data=df, kde=True, bins=30)
plt.title("Histogram of Average Age by Department")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# Identifying departments where the age and income distribution may require adjustments. For example, if one department has a higher average age and lower average income, consider exploring potential issues or implementing targeted retention strategies.
# Identifying departments with specific age group concentrations. This insight can inform HR policies and programs tailored to different age demographics.
# Identifying departments with income disparities and explore potential factors contributing to these differences. Addressing such disparities may improve overall employee satisfaction and retention.

# %% [markdown]
# # 6.Utilize predictive analytics with more advanced techniques such as regressions clustering decision trees in order identify trends from past data points then build models on those insights from different perspectives helping further prepare organizations against potential high levels involving employees departing ?

# %% [markdown]
# Hierarchical clustering

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage

# Select features for clustering
clustering_features = df[['Age', 'DailyRate', 'DistanceFromHome', 'YearsAtCompany']]

# Standardize the features
scaler = StandardScaler()
clustering_features_scaled = scaler.fit_transform(clustering_features)

# Perform hierarchical clustering
linkage_matrix = linkage(clustering_features_scaled, method='ward', metric='euclidean')

# Plot the dendrogram
plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix, p=5, truncate_mode='level', color_threshold=50, above_threshold_color='gray')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# The hierarchical clustering dendrogram reveals distinct employee clusters based on age, daily rate, distance from home, and years at the company. These clusters offer a nuanced understanding of employee groups with shared characteristics. Implementing targeted HR strategies for each cluster can enhance employee satisfaction, retention, and overall organizational performance.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Assuming 'Attrition' is the target variable
features = df[['Age', 'DailyRate', 'DistanceFromHome', 'YearsAtCompany']]
target = df['Attrition']

# Convert categorical variables to numerical using Label Encoding
le = LabelEncoder()
target = le.fit_transform(target)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a decision tree classifier
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, predictions))

# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(model, filled=True, feature_names=features.columns.tolist(), class_names=[str(x) for x in le.classes_], rounded=True)
plt.title('Decision Tree for Employee Attrition')
plt.show()
# Out:
# Accuracy: 0.7551020408163265
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       255
#            1       0.13      0.15      0.14        39
#
#     accuracy                           0.76       294
#    macro avg       0.50      0.50      0.50       294
# weighted avg       0.77      0.76      0.76       294

# %% [markdown]
# The decision tree model, trained on features like age, daily rate, distance from home, and years at the company, provides valuable insights into factors influencing employee attrition. The tree visually represents decision-making pathways, highlighting key features that contribute to attrition predictions. By interpreting the tree structure, HR teams can identify critical thresholds and patterns, allowing for targeted interventions and strategic retention efforts. The model's accuracy and classification report further quantify its predictive performance, aiding in informed decision-making for attrition mitigation.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Select relevant features and target variable
features = df[['Age', 'DailyRate', 'DistanceFromHome', 'YearsAtCompany']]
target = df['MonthlyIncome']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Plot the predicted values versus the actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions)
plt.title('Actual vs Predicted Monthly Income')
plt.xlabel('Actual Monthly Income')
plt.ylabel('Predicted Monthly Income')
plt.show()
# Out:
# Mean Squared Error: 13754156.940946251

# %% [markdown]
# The linear regression model, trained on features like age, daily rate, distance from home, and years at the company, provides a practical tool for predicting monthly income. The mean squared error, a measure of prediction accuracy, quantifies the model's performance on the test set.
#
# The scatter plot comparing actual versus predicted monthly income visually illustrates the model's effectiveness. Ideally, the points should align closely to a diagonal line, indicating accurate predictions. Deviations from the line highlight areas where the model may over-predict or under-predict income.
#
# This analysis empowers decision-makers to anticipate income levels based on employee characteristics, aiding in compensation planning and resource allocation. Continuous refinement and validation of the model can optimize its accuracy over time.

# %% [markdown]
# # Identifying performance profiles of employees at risk for attrition through predictive analytics and using this insight to create personalized development plans or retention strategies.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'Attrition' is the target variable
features = df.drop('Attrition', axis=1)  # Include all relevant features
target = df['Attrition']

# Identify and one-hot encode categorical variables
categorical_cols = features.select_dtypes(include='object').columns
features = pd.get_dummies(features, columns=categorical_cols, drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a random forest classifier for predicting attrition
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, predictions))

# Plot feature importance
feature_importance = model.feature_importances_
feature_names = features.columns
sorted_idx = feature_importance.argsort()

plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), feature_names[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Random Forest Feature Importance for Employee Attrition')
plt.show()
# Out:
# Accuracy: 0.8775510204081632
#               precision    recall  f1-score   support
#
#           No       0.88      1.00      0.93       255
#          Yes       0.80      0.10      0.18        39
#
#     accuracy                           0.88       294
#    macro avg       0.84      0.55      0.56       294
# weighted avg       0.87      0.88      0.83       294

# %% [markdown]
# The feature importance plot from the Random Forest classifier provides a concise business insight by highlighting the most influential factors in predicting employee attrition. Business leaders can prioritize interventions and strategic efforts based on these key features, optimizing resources for targeted improvements in employee retention.

# %% [markdown]
# # Using the data to assess the impact of different financial incentives or variations in job role/structure on employee attitudes, satisfaction and ultimately attrition rates.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'Attrition' is the target variable
features = df[['Age', 'BusinessTravel', 'DailyRate', 'Department',
               'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
               'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
               'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
               'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
               'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
               'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
               'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
               'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
               'YearsWithCurrManager']]

target = df['Attrition']

# One-hot encode categorical variables
features = pd.get_dummies(features, columns=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'], drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a random forest classifier for predicting attrition
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Feature Importance Plot using Bar Plot
feature_importance = model.feature_importances_
feature_names = features.columns
sorted_idx = feature_importance.argsort()

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, predictions))


plt.figure(figsize=(10, 8))
sns.barplot(x=feature_importance[sorted_idx], y=feature_names[sorted_idx], palette='viridis')
plt.xlabel('Feature Importance')
plt.title('Random Forest Feature Importance for Employee Attrition')
plt.show()

# Violin Plot for Monthly Income by Attrition
plt.figure(figsize=(12, 6))
sns.violinplot(x='Attrition', y='MonthlyIncome', data=df, palette='Set2')
plt.title('Monthly Income Distribution by Attrition')
plt.show()
# Out:
# Accuracy: 0.8775510204081632
#               precision    recall  f1-score   support
#
#           No       0.88      1.00      0.93       255
#          Yes       0.80      0.10      0.18        39
#
#     accuracy                           0.88       294
#    macro avg       0.84      0.55      0.56       294
# weighted avg       0.87      0.88      0.83       294

# %% [markdown]
# The Random Forest model was trained to predict employee attrition based on various features. The feature importance bar plot indicates that Monthly Income, Total Working Years, and Age are the most influential factors in predicting attrition.
#
# Monthly Income Importance:
#
# Employees with lower monthly income are more likely to experience attrition.
# Total Working Years Importance:
#
# Longer total working years tend to be associated with lower attrition rates.
# Age Importance:
#
# Younger employees are more likely to leave the organization.
#
# The violin plot shows the distribution of Monthly Income by Attrition. It illustrates that employees who leave tend to have lower monthly incomes compared to those who stay.

# %% [markdown]
# # Analyzing different age groups' responses to various perks or turnover patterns in order to understand how organizations can better engage different demographic segments.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'Attrition' is the target variable
features = df[['Age', 'JobSatisfaction', 'WorkLifeBalance', 'StockOptionLevel', 'YearsInCurrentRole']]

target = df['Attrition']

# One-hot encode categorical variables if needed

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a random forest classifier for predicting attrition
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, predictions))

# Create age groups (e.g., 20-30, 31-40, 41-50, 51-60, 60+)
age_bins = [20, 30, 40, 50, 60, 100]
age_labels = ['20-30', '31-40', '41-50', '51-60', '60+']
df['AgeGroup'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Visualize responses across age groups using bar plots
plt.figure(figsize=(15, 8))
sns.barplot(x='AgeGroup', y='JobSatisfaction', data=df, hue='Attrition', palette='Set1')
plt.title('Job Satisfaction Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Job Satisfaction')
plt.show()

plt.figure(figsize=(15, 8))
sns.barplot(x='AgeGroup', y='WorkLifeBalance', data=df, hue='Attrition', palette='Set2')
plt.title('Work-Life Balance Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Work-Life Balance')
plt.show()

plt.figure(figsize=(15, 8))
sns.barplot(x='AgeGroup', y='StockOptionLevel', data=df, hue='Attrition', palette='Set3')
plt.title('Stock Option Level Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Stock Option Level')
plt.show()

plt.figure(figsize=(15, 8))
sns.barplot(x='AgeGroup', y='YearsInCurrentRole', data=df, hue='Attrition', palette='Set1')  # Choose a valid palette
plt.title('Years in Current Role Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Years in Current Role')
plt.show()
# Out:
# Accuracy: 0.8129251700680272
#               precision    recall  f1-score   support
#
#           No       0.88      0.91      0.89       255
#          Yes       0.21      0.15      0.18        39
#
#     accuracy                           0.81       294
#    macro avg       0.55      0.53      0.54       294
# weighted avg       0.79      0.81      0.80       294

# %% [markdown]
# The visualization of employee attributes across different age groups highlights potential areas of concern for attrition. Younger employees, especially in the 20-30 age group, show lower satisfaction levels in job-related factors and work-life balance. Addressing these concerns through targeted interventions and benefits adjustments may enhance overall employee retention and satisfaction.

# %% [markdown]
# # Apply the studied statistical methods

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'Age', 'JobSatisfaction', 'WorkLifeBalance', 'StockOptionLevel', and 'YearsInCurrentRole' are columns in the DataFrame

# Select relevant columns
selected_columns = ['Age', 'JobSatisfaction', 'WorkLifeBalance', 'StockOptionLevel', 'YearsInCurrentRole']
correlation_df = df[selected_columns]

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()

# Generate a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Selected Attributes')
plt.show()

# %% [markdown]
# The correlation heatmap reveals insights into potential relationships among employee attributes. Notable findings include a positive correlation between job satisfaction and work-life balance, suggesting that employees who are satisfied with their jobs tend to have a better work-life balance. Additionally, age shows a slight negative correlation with stock option level, implying that younger employees may have lower stock option levels. These insights can guide HR in tailoring strategies to enhance job satisfaction, work-life balance, and benefits alignment with different age groups, contributing to improved employee retention.
